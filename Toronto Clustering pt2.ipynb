# %% [markdown]
# # Clustering Toronto

# %% [markdown]
# ### Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Wikipedia API endpoint

# %%
url = 'https://en.wikipedia.org/w/api.php?action=query&prop=revisions&rvprop=content&format=json&formatversion=2&titles=List_of_postal_codes_of_Canada:_M'

# %%
#get request
results = requests.get(url).json()

# %%
content = results["query"]["pages"][0]["revisions"][0]["content"].split("class=\"wikitable sortable\"\n! ")[1].split("{{col-begin}}")[0]

# %% [markdown]
# ### Clean this mess of data

# %%
rows = content.split("\n")

# %%
newrows = []
for row in rows:
    if row != ('|-'):
        newrows.append(row.split("||"))

# %% [markdown]
# #### Building lists

# %%
borough = []
neighborhood = []
code = []

for i in range(1,289):
    code.append(newrows[i][0].split(' ')[1])
    borough.append(newrows[i][1])
    neighborhood.append(newrows[i][2])

# %% [markdown]
# #### Building a DataFrame

# %%
df = pd.DataFrame({'PostalCode':code,'Borough':borough,'Neighborhood':neighborhood})

# %% [markdown]
# #### Cleaning all this weirdness

# %%
cleanDf = df.applymap(lambda x: x.strip() if isinstance(x,str) else x)

# %%
cleanDf['Borough'] = cleanDf['Borough'].str.strip('[[]]').astype(str)

# %%
cleanDf['Neighborhood'] = cleanDf['Neighborhood'].str.strip('[[]]').astype(str)

# %%
for i in range(len(cleanDf)):
    cleanDf['Borough'][i] = cleanDf['Borough'][i].replace("|",", ")
    cleanDf['Neighborhood'][i] = cleanDf['Neighborhood'][i].replace("|",", ")

# %% [markdown]
# #### Taking a second to check

# %%
cleanDf.head(5)
# Out:
#   PostalCode           Borough                          Neighborhood
# 0        M1A      Not assigned                          Not assigned
# 1        M2A      Not assigned                          Not assigned
# 2        M3A        North York                             Parkwoods
# 3        M4A        North York                      Victoria Village
# 4        M5A  Downtown Toronto  Harbourfront (Toronto), Harbourfront

# %% [markdown]
# ### Group by Postalcode set Neighborhoods value to Borough value where Neighborhood is N/A

# %%
newDf = cleanDf.groupby('PostalCode').agg({'Borough':'first','Neighborhood': ', '.join}).reset_index()

# %%
newDf = newDf.applymap(lambda x: x.strip() if isinstance(x,str) else x)

# %%
for i in range (0,len(newDf)):
    if newDf['Neighborhood'][i] == 'Not assigned':
        newDf.at[i,'Neighborhood'] = newDf['Borough'][i]

# %%
newDf
# Out:
#     PostalCode                               Borough  \
# 0          M1A                          Not assigned
# 1          M1B     Scarborough, Toronto, Scarborough
# 2          M1C     Scarborough, Toronto, Scarborough
# 3          M1E     Scarborough, Toronto, Scarborough
# 4          M1G     Scarborough, Toronto, Scarborough
# 5          M1H     Scarborough, Toronto, Scarborough
# 6          M1J     Scarborough, Toronto, Scarborough
# 7          M1K     Scarborough, Toronto, Scarborough
# 8          M1L     Scarborough, Toronto, Scarborough
# 9          M1M     Scarborough, Toronto, Scarborough
# 10         M1N     Scarborough, Toronto, Scarborough
# 11         M1P     Scarborough, Toronto, Scarborough
# 12         M1R     Scarborough, Toronto, Scarborough
# 13         M1S     Scarborough, Toronto, Scarborough
# 14         M1T     Scarborough, Toronto, Scarborough
# 15         M1V     Scarborough, Toronto, Scarborough
# 16         M1W     Scarborough, Toronto, Scarborough
# 17         M1X     Scarborough, Toronto, Scarborough
# 18         M1Y                          Not assigned
# 19         M1Z                          Not assigned
# 20         M2A                          Not assigned
# 21         M2B                          Not assigned
# 22         M2C                          Not assigned
# 23         M2E                          Not assigned
# 24         M2G                          Not assigned
# 25         M2H                            North York
# 26         M2J                            North York
# 27         M2K                            North York
# 28         M2L                            North York
# 29         M2M                            North York
# 30         M2N                            North York
# 31         M2P                            North York
# 32         M2R                            North York
# 33         M2S                          Not assigned
# 34         M2T                          Not assigned
# 35         M2V                          Not assigned
# 36         M2W                          Not assigned
# 37         M2X                          Not assigned
# 38         M2Y                          Not assigned
# 39         M2Z                          Not assigned
# 40         M3A                            North York
# 41         M3B                            North York
# 42         M3C                            North York
# 43         M3E                          Not assigned
# 44         M3G                          Not assigned
# 45         M3H                            North York
# 46         M3J                            North York
# 47         M3K                            North York
# 48         M3L                            North York
# 49         M3M                            North York
# 50         M3N                            North York
# 51         M3P                          Not assigned
# 52         M3R                          Not assigned
# 53         M3S                          Not assigned
# 54         M3T                          Not assigned
# 55         M3V                          Not assigned
# 56         M3W                          Not assigned
# 57         M3X                          Not assigned
# 58         M3Y                          Not assigned
# 59         M3Z                          Not assigned
# 60         M4A                            North York
# 61         M4B                             East York
# 62         M4C                             East York
# 63         M4E                          East Toronto
# 64         M4G                             East York
# 65         M4H                             East York
# 66         M4J                             East York
# 67         M4K                          East Toronto
# 68         M4L                          East Toronto
# 69         M4M                          East Toronto
# 70         M4N                       Central Toronto
# 71         M4P                       Central Toronto
# 72         M4R                       Central Toronto
# 73         M4S                       Central Toronto
# 74         M4T                       Central Toronto
# 75         M4V                       Central Toronto
# 76         M4W                      Downtown Toronto
# 77         M4X                      Downtown Toronto
# 78         M4Y                      Downtown Toronto
# 79         M4Z                          Not assigned
# 80         M5A                      Downtown Toronto
# 81         M5B                      Downtown Toronto
# 82         M5C                      Downtown Toronto
# 83         M5E                      Downtown Toronto
# 84         M5G                      Downtown Toronto
# 85         M5H                      Downtown Toronto
# 86         M5J                      Downtown Toronto
# 87         M5K                      Downtown Toronto
# 88         M5L                      Downtown Toronto
# 89         M5M                            North York
# 90         M5N                       Central Toronto
# 91         M5P                       Central Toronto
# 92         M5R                       Central Toronto
# 93         M5S                      Downtown Toronto
# 94         M5T                      Downtown Toronto
# 95         M5V                      Downtown Toronto
# 96         M5W                      Downtown Toronto
# 97         M5X                      Downtown Toronto
# 98         M5Y                          Not assigned
# 99         M5Z                          Not assigned
# 100        M6A                            North York
# 101        M6B                            North York
# 102        M6C                                  York
# 103        M6E                                  York
# 104        M6G                      Downtown Toronto
# 105        M6H                          West Toronto
# 106        M6J                          West Toronto
# 107        M6K                          West Toronto
# 108        M6L                            North York
# 109        M6M                                  York
# 110        M6N                                  York
# 111        M6P                          West Toronto
# 112        M6R                          West Toronto
# 113        M6S                          West Toronto
# 114        M6T                          Not assigned
# 115        M6V                          Not assigned
# 116        M6W                          Not assigned
# 117        M6X                          Not assigned
# 118        M6Y                          Not assigned
# 119        M6Z                          Not assigned
# 120        M7A  Queen's Park (Toronto), Queen's Park
# 121        M7B                          Not assigned
# 122        M7C                          Not assigned
# 123        M7E                          Not assigned
# 124        M7G                          Not assigned
# 125        M7H                          Not assigned
# 126        M7J                          Not assigned
# 127        M7K                          Not assigned
# 128        M7L                          Not assigned
# 129        M7M                          Not assigned
# 130        M7N                          Not assigned
# 131        M7P                          Not assigned
# 132        M7R                           Mississauga
# 133        M7S                          Not assigned
# 134        M7T                          Not assigned
# 135        M7V                          Not assigned
# 136        M7W                          Not assigned
# 137        M7X                          Not assigned
# 138        M7Y                          East Toronto
# 139        M7Z                          Not assigned
# 140        M8A                          Not assigned
# 141        M8B                          Not assigned
# 142        M8C                          Not assigned
# 143        M8E                          Not assigned
# 144        M8G                          Not assigned
# 145        M8H                          Not assigned
# 146        M8J                          Not assigned
# 147        M8K                          Not assigned
# 148        M8L                          Not assigned
# 149        M8M                          Not assigned
# 150        M8N                          Not assigned
# 151        M8P                          Not assigned
# 152        M8R                          Not assigned
# 153        M8S                          Not assigned
# 154        M8T                          Not assigned
# 155        M8V                             Etobicoke
# 156        M8W                             Etobicoke
# 157        M8X                             Etobicoke
# 158        M8Y                             Etobicoke
# 159        M8Z                             Etobicoke
# 160        M9A                             Etobicoke
# 161        M9B                             Etobicoke
# 162        M9C                             Etobicoke
# 163        M9E                          Not assigned
# 164        M9G                          Not assigned
# 165        M9H                          Not assigned
# 166        M9J                          Not assigned
# 167        M9K                          Not assigned
# 168        M9L                            North York
# 169        M9M                            North York
# 170        M9N                                  York
# 171        M9P                             Etobicoke
# 172        M9R                             Etobicoke
# 173        M9S                          Not assigned
# 174        M9T                          Not assigned
# 175        M9V                             Etobicoke
# 176        M9W                             Etobicoke
# 177        M9X                          Not assigned
# 178        M9Y                          Not assigned
# 179        M9Z                          Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1     Rouge, Toronto, Rouge, Malvern, Toronto, Malvern
# 2    Highland Creek (Toronto), Highland Creek, Roug...
# 3    Guildwood, Morningside, Toronto, Morningside, ...
# 4                              Woburn, Toronto, Woburn
# 5                                            Cedarbrae
# 6                                  Scarborough Village
# 7    East Birchmount Park, Ionview, Kennedy Park, T...
# 8    Clairlea, Golden Mile, Toronto, Golden Mile, O...
# 9    Cliffcrest, Cliffside, Toronto, Cliffside, Sca...
# 10                         Birch Cliff, Cliffside West
# 11   Dorset Park, Scarborough Town Centre, Wexford ...
# 12   Maryvale, Toronto, Maryvale, Wexford, Toronto,...
# 13                       Agincourt, Toronto, Agincourt
# 14   Clarks Corners, Sullivan, Tam O'Shanter – Sull...
# 15   Agincourt North, L'Amoreaux East, Milliken, On...
# 16                                     L'Amoreaux West
# 17                                         Upper Rouge
# 18                                        Not assigned
# 19                                        Not assigned
# 20                                        Not assigned
# 21                                        Not assigned
# 22                                        Not assigned
# 23                                        Not assigned
# 24                                        Not assigned
# 25                                   Hillcrest Village
# 26                        Fairview, Henry Farm, Oriole
# 27                                     Bayview Village
# 28                            Silver Hills, York Mills
# 29        Newtonbrook, Willowdale, Toronto, Willowdale
# 30                                    Willowdale South
# 31                                     York Mills West
# 32                                     Willowdale West
# 33                                        Not assigned
# 34                                        Not assigned
# 35                                        Not assigned
# 36                                        Not assigned
# 37                                        Not assigned
# 38                                        Not assigned
# 39                                        Not assigned
# 40                                           Parkwoods
# 41                                     Don Mills North
# 42                    Flemingdon Park, Don Mills South
# 43                                        Not assigned
# 44                                        Not assigned
# 45   Bathurst Manor, Downsview North, Wilson Height...
# 46                     Northwood Park, York University
# 47                         CFB Toronto, Downsview East
# 48                           Downsview, Downsview West
# 49                                   Downsview Central
# 50                                 Downsview Northwest
# 51                                        Not assigned
# 52                                        Not assigned
# 53                                        Not assigned
# 54                                        Not assigned
# 55                                        Not assigned
# 56                                        Not assigned
# 57                                        Not assigned
# 58                                        Not assigned
# 59                                        Not assigned
# 60                                    Victoria Village
# 61                     Woodbine Gardens, Parkview Hill
# 62                                    Woodbine Heights
# 63                                         The Beaches
# 64                                             Leaside
# 65                                    Thorncliffe Park
# 66                                        East Toronto
# 67    The Danforth West, Riverdale, Toronto, Riverdale
# 68                      The Beaches West, India Bazaar
# 69                                     Studio District
# 70               Lawrence Park, Toronto, Lawrence Park
# 71                                    Davisville North
# 72                                  North Toronto West
# 73                                          Davisville
# 74    Moore Park, Toronto, Moore Park, Summerhill East
# 75   Deer Park, Toronto, Deer Park, Forest Hill SE,...
# 76                         Rosedale, Toronto, Rosedale
# 77   Cabbagetown, Toronto, Cabbagetown, St. James Town
# 78                                Church and Wellesley
# 79                                        Not assigned
# 80   Harbourfront (Toronto), Harbourfront, Regent Park
# 81                            Ryerson, Garden District
# 82                                      St. James Town
# 83                                         Berczy Park
# 84                                  Central Bay Street
# 85                            Adelaide, King, Richmond
# 86   Harbourfront East, Toronto Islands, Union Stat...
# 87            Design Exchange, Toronto Dominion Centre
# 88                      Commerce Court, Victoria Hotel
# 89   Bedford Park, Toronto, Bedford Park, Lawrence ...
# 90                                            Roselawn
# 91                 Forest Hill North, Forest Hill West
# 92   The Annex, North Midtown, Yorkville, Toronto, ...
# 93                      Harbord, University of Toronto
# 94   Chinatown, Toronto, Chinatown, Grange Park (To...
# 95   CN Tower, Bathurst Quay, Island airport, Harbo...
# 96                     Stn A PO Boxes 25 The Esplanade
# 97              First Canadian Place, Underground city
# 98                                        Not assigned
# 99                                        Not assigned
# 100                   Lawrence Heights, Lawrence Manor
# 101                                          Glencairn
# 102                                 Humewood-Cedarvale
# 103                                Caledonia-Fairbanks
# 104                                           Christie
# 105                       Dovercourt Village, Dufferin
# 106  Little Portugal, Toronto, Little Portugal, Tri...
# 107       Brockton, Exhibition Place, Parkdale Village
# 108  Downsview, Toronto, Downsview, North Park, Upw...
# 109  Del Ray, Keelesdale, Mount Dennis, Silverthorn...
# 110                      The Junction North, Runnymede
# 111                      High Park, The Junction South
# 112  Parkdale, Toronto, Parkdale, Roncesvalles, Tor...
# 113  Runnymede, Toronto, Runnymede, Swansea, Toront...
# 114                                       Not assigned
# 115                                       Not assigned
# 116                                       Not assigned
# 117                                       Not assigned
# 118                                       Not assigned
# 119                                       Not assigned
# 120               Queen's Park (Toronto), Queen's Park
# 121                                       Not assigned
# 122                                       Not assigned
# 123                                       Not assigned
# 124                                       Not assigned
# 125                                       Not assigned
# 126                                       Not assigned
# 127                                       Not assigned
# 128                                       Not assigned
# 129                                       Not assigned
# 130                                       Not assigned
# 131                                       Not assigned
# 132              Canada Post Gateway Processing Centre
# 133                                       Not assigned
# 134                                       Not assigned
# 135                                       Not assigned
# 136                                       Not assigned
# 137                                       Not assigned
# 138  Business Reply Mail Processing Centre 969 Eastern
# 139                                       Not assigned
# 140                                       Not assigned
# 141                                       Not assigned
# 142                                       Not assigned
# 143                                       Not assigned
# 144                                       Not assigned
# 145                                       Not assigned
# 146                                       Not assigned
# 147                                       Not assigned
# 148                                       Not assigned
# 149                                       Not assigned
# 150                                       Not assigned
# 151                                       Not assigned
# 152                                       Not assigned
# 153                                       Not assigned
# 154                                       Not assigned
# 155       Humber Bay Shores, Mimico South, New Toronto
# 156  Alderwood, Toronto, Alderwood, Long Branch, To...
# 157      The Kingsway, Montgomery Road, Old Mill North
# 158  Humber Bay, King's Mill Park, Kingsway Park So...
# 159  Kingsway Park South West, Mimico, Mimico NW, T...
# 160                                   Islington Avenue
# 161  Cloverdale, Islington, Toronto, Islington, Mar...
# 162  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 163                                       Not assigned
# 164                                       Not assigned
# 165                                       Not assigned
# 166                                       Not assigned
# 167                                       Not assigned
# 168                                      Humber Summit
# 169                   Emery, Toronto, Emery, Humberlea
# 170                            Weston, Toronto, Weston
# 171                                          Westmount
# 172  Kingsview Village, Martin Grove Gardens, Richv...
# 173                                       Not assigned
# 174                                       Not assigned
# 175  Albion Gardens, Beaumond Heights, Humbergate, ...
# 176                                          Northwest
# 177                                       Not assigned
# 178                                       Not assigned
# 179                                       Not assigned

# %%
newDf.shape
# Out:
# (180, 3)

# %%
print('Total number of rows: ',newDf.shape[0])
# Out:
# Total number of rows:  180

# %% [markdown]
# ## Import Geospatial Data

# %%
geo = pd.read_csv('http://cocl.us/Geospatial_data')

# %%
geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ### Merge Geospatial data and Dataframe

# %%
df3 = pd.merge(newDf,geo,left_on='PostalCode',right_on='Postal Code', how='left')

# %%
df3.drop(columns='Postal Code',inplace=True)

# %%
df3
# Out:
#     PostalCode                               Borough  \
# 0          M1A                          Not assigned
# 1          M1B     Scarborough, Toronto, Scarborough
# 2          M1C     Scarborough, Toronto, Scarborough
# 3          M1E     Scarborough, Toronto, Scarborough
# 4          M1G     Scarborough, Toronto, Scarborough
# 5          M1H     Scarborough, Toronto, Scarborough
# 6          M1J     Scarborough, Toronto, Scarborough
# 7          M1K     Scarborough, Toronto, Scarborough
# 8          M1L     Scarborough, Toronto, Scarborough
# 9          M1M     Scarborough, Toronto, Scarborough
# 10         M1N     Scarborough, Toronto, Scarborough
# 11         M1P     Scarborough, Toronto, Scarborough
# 12         M1R     Scarborough, Toronto, Scarborough
# 13         M1S     Scarborough, Toronto, Scarborough
# 14         M1T     Scarborough, Toronto, Scarborough
# 15         M1V     Scarborough, Toronto, Scarborough
# 16         M1W     Scarborough, Toronto, Scarborough
# 17         M1X     Scarborough, Toronto, Scarborough
# 18         M1Y                          Not assigned
# 19         M1Z                          Not assigned
# 20         M2A                          Not assigned
# 21         M2B                          Not assigned
# 22         M2C                          Not assigned
# 23         M2E                          Not assigned
# 24         M2G                          Not assigned
# 25         M2H                            North York
# 26         M2J                            North York
# 27         M2K                            North York
# 28         M2L                            North York
# 29         M2M                            North York
# 30         M2N                            North York
# 31         M2P                            North York
# 32         M2R                            North York
# 33         M2S                          Not assigned
# 34         M2T                          Not assigned
# 35         M2V                          Not assigned
# 36         M2W                          Not assigned
# 37         M2X                          Not assigned
# 38         M2Y                          Not assigned
# 39         M2Z                          Not assigned
# 40         M3A                            North York
# 41         M3B                            North York
# 42         M3C                            North York
# 43         M3E                          Not assigned
# 44         M3G                          Not assigned
# 45         M3H                            North York
# 46         M3J                            North York
# 47         M3K                            North York
# 48         M3L                            North York
# 49         M3M                            North York
# 50         M3N                            North York
# 51         M3P                          Not assigned
# 52         M3R                          Not assigned
# 53         M3S                          Not assigned
# 54         M3T                          Not assigned
# 55         M3V                          Not assigned
# 56         M3W                          Not assigned
# 57         M3X                          Not assigned
# 58         M3Y                          Not assigned
# 59         M3Z                          Not assigned
# 60         M4A                            North York
# 61         M4B                             East York
# 62         M4C                             East York
# 63         M4E                          East Toronto
# 64         M4G                             East York
# 65         M4H                             East York
# 66         M4J                             East York
# 67         M4K                          East Toronto
# 68         M4L                          East Toronto
# 69         M4M                          East Toronto
# 70         M4N                       Central Toronto
# 71         M4P                       Central Toronto
# 72         M4R                       Central Toronto
# 73         M4S                       Central Toronto
# 74         M4T                       Central Toronto
# 75         M4V                       Central Toronto
# 76         M4W                      Downtown Toronto
# 77         M4X                      Downtown Toronto
# 78         M4Y                      Downtown Toronto
# 79         M4Z                          Not assigned
# 80         M5A                      Downtown Toronto
# 81         M5B                      Downtown Toronto
# 82         M5C                      Downtown Toronto
# 83         M5E                      Downtown Toronto
# 84         M5G                      Downtown Toronto
# 85         M5H                      Downtown Toronto
# 86         M5J                      Downtown Toronto
# 87         M5K                      Downtown Toronto
# 88         M5L                      Downtown Toronto
# 89         M5M                            North York
# 90         M5N                       Central Toronto
# 91         M5P                       Central Toronto
# 92         M5R                       Central Toronto
# 93         M5S                      Downtown Toronto
# 94         M5T                      Downtown Toronto
# 95         M5V                      Downtown Toronto
# 96         M5W                      Downtown Toronto
# 97         M5X                      Downtown Toronto
# 98         M5Y                          Not assigned
# 99         M5Z                          Not assigned
# 100        M6A                            North York
# 101        M6B                            North York
# 102        M6C                                  York
# 103        M6E                                  York
# 104        M6G                      Downtown Toronto
# 105        M6H                          West Toronto
# 106        M6J                          West Toronto
# 107        M6K                          West Toronto
# 108        M6L                            North York
# 109        M6M                                  York
# 110        M6N                                  York
# 111        M6P                          West Toronto
# 112        M6R                          West Toronto
# 113        M6S                          West Toronto
# 114        M6T                          Not assigned
# 115        M6V                          Not assigned
# 116        M6W                          Not assigned
# 117        M6X                          Not assigned
# 118        M6Y                          Not assigned
# 119        M6Z                          Not assigned
# 120        M7A  Queen's Park (Toronto), Queen's Park
# 121        M7B                          Not assigned
# 122        M7C                          Not assigned
# 123        M7E                          Not assigned
# 124        M7G                          Not assigned
# 125        M7H                          Not assigned
# 126        M7J                          Not assigned
# 127        M7K                          Not assigned
# 128        M7L                          Not assigned
# 129        M7M                          Not assigned
# 130        M7N                          Not assigned
# 131        M7P                          Not assigned
# 132        M7R                           Mississauga
# 133        M7S                          Not assigned
# 134        M7T                          Not assigned
# 135        M7V                          Not assigned
# 136        M7W                          Not assigned
# 137        M7X                          Not assigned
# 138        M7Y                          East Toronto
# 139        M7Z                          Not assigned
# 140        M8A                          Not assigned
# 141        M8B                          Not assigned
# 142        M8C                          Not assigned
# 143        M8E                          Not assigned
# 144        M8G                          Not assigned
# 145        M8H                          Not assigned
# 146        M8J                          Not assigned
# 147        M8K                          Not assigned
# 148        M8L                          Not assigned
# 149        M8M                          Not assigned
# 150        M8N                          Not assigned
# 151        M8P                          Not assigned
# 152        M8R                          Not assigned
# 153        M8S                          Not assigned
# 154        M8T                          Not assigned
# 155        M8V                             Etobicoke
# 156        M8W                             Etobicoke
# 157        M8X                             Etobicoke
# 158        M8Y                             Etobicoke
# 159        M8Z                             Etobicoke
# 160        M9A                             Etobicoke
# 161        M9B                             Etobicoke
# 162        M9C                             Etobicoke
# 163        M9E                          Not assigned
# 164        M9G                          Not assigned
# 165        M9H                          Not assigned
# 166        M9J                          Not assigned
# 167        M9K                          Not assigned
# 168        M9L                            North York
# 169        M9M                            North York
# 170        M9N                                  York
# 171        M9P                             Etobicoke
# 172        M9R                             Etobicoke
# 173        M9S                          Not assigned
# 174        M9T                          Not assigned
# 175        M9V                             Etobicoke
# 176        M9W                             Etobicoke
# 177        M9X                          Not assigned
# 178        M9Y                          Not assigned
# 179        M9Z                          Not assigned
#
#                                           Neighborhood   Latitude  Longitude
# 0                                         Not assigned        NaN        NaN
# 1     Rouge, Toronto, Rouge, Malvern, Toronto, Malvern  43.806686 -79.194353
# 2    Highland Creek (Toronto), Highland Creek, Roug...  43.784535 -79.160497
# 3    Guildwood, Morningside, Toronto, Morningside, ...  43.763573 -79.188711
# 4                              Woburn, Toronto, Woburn  43.770992 -79.216917
# 5                                            Cedarbrae  43.773136 -79.239476
# 6                                  Scarborough Village  43.744734 -79.239476
# 7    East Birchmount Park, Ionview, Kennedy Park, T...  43.727929 -79.262029
# 8    Clairlea, Golden Mile, Toronto, Golden Mile, O...  43.711112 -79.284577
# 9    Cliffcrest, Cliffside, Toronto, Cliffside, Sca...  43.716316 -79.239476
# 10                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 11   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 12   Maryvale, Toronto, Maryvale, Wexford, Toronto,...  43.750072 -79.295849
# 13                       Agincourt, Toronto, Agincourt  43.794200 -79.262029
# 14   Clarks Corners, Sullivan, Tam O'Shanter – Sull...  43.781638 -79.304302
# 15   Agincourt North, L'Amoreaux East, Milliken, On...  43.815252 -79.284577
# 16                                     L'Amoreaux West  43.799525 -79.318389
# 17                                         Upper Rouge  43.836125 -79.205636
# 18                                        Not assigned        NaN        NaN
# 19                                        Not assigned        NaN        NaN
# 20                                        Not assigned        NaN        NaN
# 21                                        Not assigned        NaN        NaN
# 22                                        Not assigned        NaN        NaN
# 23                                        Not assigned        NaN        NaN
# 24                                        Not assigned        NaN        NaN
# 25                                   Hillcrest Village  43.803762 -79.363452
# 26                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 27                                     Bayview Village  43.786947 -79.385975
# 28                            Silver Hills, York Mills  43.757490 -79.374714
# 29        Newtonbrook, Willowdale, Toronto, Willowdale  43.789053 -79.408493
# 30                                    Willowdale South  43.770120 -79.408493
# 31                                     York Mills West  43.752758 -79.400049
# 32                                     Willowdale West  43.782736 -79.442259
# 33                                        Not assigned        NaN        NaN
# 34                                        Not assigned        NaN        NaN
# 35                                        Not assigned        NaN        NaN
# 36                                        Not assigned        NaN        NaN
# 37                                        Not assigned        NaN        NaN
# 38                                        Not assigned        NaN        NaN
# 39                                        Not assigned        NaN        NaN
# 40                                           Parkwoods  43.753259 -79.329656
# 41                                     Don Mills North  43.745906 -79.352188
# 42                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 43                                        Not assigned        NaN        NaN
# 44                                        Not assigned        NaN        NaN
# 45   Bathurst Manor, Downsview North, Wilson Height...  43.754328 -79.442259
# 46                     Northwood Park, York University  43.767980 -79.487262
# 47                         CFB Toronto, Downsview East  43.737473 -79.464763
# 48                           Downsview, Downsview West  43.739015 -79.506944
# 49                                   Downsview Central  43.728496 -79.495697
# 50                                 Downsview Northwest  43.761631 -79.520999
# 51                                        Not assigned        NaN        NaN
# 52                                        Not assigned        NaN        NaN
# 53                                        Not assigned        NaN        NaN
# 54                                        Not assigned        NaN        NaN
# 55                                        Not assigned        NaN        NaN
# 56                                        Not assigned        NaN        NaN
# 57                                        Not assigned        NaN        NaN
# 58                                        Not assigned        NaN        NaN
# 59                                        Not assigned        NaN        NaN
# 60                                    Victoria Village  43.725882 -79.315572
# 61                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 62                                    Woodbine Heights  43.695344 -79.318389
# 63                                         The Beaches  43.676357 -79.293031
# 64                                             Leaside  43.709060 -79.363452
# 65                                    Thorncliffe Park  43.705369 -79.349372
# 66                                        East Toronto  43.685347 -79.338106
# 67    The Danforth West, Riverdale, Toronto, Riverdale  43.679557 -79.352188
# 68                      The Beaches West, India Bazaar  43.668999 -79.315572
# 69                                     Studio District  43.659526 -79.340923
# 70               Lawrence Park, Toronto, Lawrence Park  43.728020 -79.388790
# 71                                    Davisville North  43.712751 -79.390197
# 72                                  North Toronto West  43.715383 -79.405678
# 73                                          Davisville  43.704324 -79.388790
# 74    Moore Park, Toronto, Moore Park, Summerhill East  43.689574 -79.383160
# 75   Deer Park, Toronto, Deer Park, Forest Hill SE,...  43.686412 -79.400049
# 76                         Rosedale, Toronto, Rosedale  43.679563 -79.377529
# 77   Cabbagetown, Toronto, Cabbagetown, St. James Town  43.667967 -79.367675
# 78                                Church and Wellesley  43.665860 -79.383160
# 79                                        Not assigned        NaN        NaN
# 80   Harbourfront (Toronto), Harbourfront, Regent Park  43.654260 -79.360636
# 81                            Ryerson, Garden District  43.657162 -79.378937
# 82                                      St. James Town  43.651494 -79.375418
# 83                                         Berczy Park  43.644771 -79.373306
# 84                                  Central Bay Street  43.657952 -79.387383
# 85                            Adelaide, King, Richmond  43.650571 -79.384568
# 86   Harbourfront East, Toronto Islands, Union Stat...  43.640816 -79.381752
# 87            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 88                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 89   Bedford Park, Toronto, Bedford Park, Lawrence ...  43.733283 -79.419750
# 90                                            Roselawn  43.711695 -79.416936
# 91                 Forest Hill North, Forest Hill West  43.696948 -79.411307
# 92   The Annex, North Midtown, Yorkville, Toronto, ...  43.672710 -79.405678
# 93                      Harbord, University of Toronto  43.662696 -79.400049
# 94   Chinatown, Toronto, Chinatown, Grange Park (To...  43.653206 -79.400049
# 95   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 96                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98                                        Not assigned        NaN        NaN
# 99                                        Not assigned        NaN        NaN
# 100                   Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 101                                          Glencairn  43.709577 -79.445073
# 102                                 Humewood-Cedarvale  43.693781 -79.428191
# 103                                Caledonia-Fairbanks  43.689026 -79.453512
# 104                                           Christie  43.669542 -79.422564
# 105                       Dovercourt Village, Dufferin  43.669005 -79.442259
# 106  Little Portugal, Toronto, Little Portugal, Tri...  43.647927 -79.419750
# 107       Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 108  Downsview, Toronto, Downsview, North Park, Upw...  43.713756 -79.490074
# 109  Del Ray, Keelesdale, Mount Dennis, Silverthorn...  43.691116 -79.476013
# 110                      The Junction North, Runnymede  43.673185 -79.487262
# 111                      High Park, The Junction South  43.661608 -79.464763
# 112  Parkdale, Toronto, Parkdale, Roncesvalles, Tor...  43.648960 -79.456325
# 113  Runnymede, Toronto, Runnymede, Swansea, Toront...  43.651571 -79.484450
# 114                                       Not assigned        NaN        NaN
# 115                                       Not assigned        NaN        NaN
# 116                                       Not assigned        NaN        NaN
# 117                                       Not assigned        NaN        NaN
# 118                                       Not assigned        NaN        NaN
# 119                                       Not assigned        NaN        NaN
# 120               Queen's Park (Toronto), Queen's Park  43.662301 -79.389494
# 121                                       Not assigned        NaN        NaN
# 122                                       Not assigned        NaN        NaN
# 123                                       Not assigned        NaN        NaN
# 124                                       Not assigned        NaN        NaN
# 125                                       Not assigned        NaN        NaN
# 126                                       Not assigned        NaN        NaN
# 127                                       Not assigned        NaN        NaN
# 128                                       Not assigned        NaN        NaN
# 129                                       Not assigned        NaN        NaN
# 130                                       Not assigned        NaN        NaN
# 131                                       Not assigned        NaN        NaN
# 132              Canada Post Gateway Processing Centre  43.636966 -79.615819
# 133                                       Not assigned        NaN        NaN
# 134                                       Not assigned        NaN        NaN
# 135                                       Not assigned        NaN        NaN
# 136                                       Not assigned        NaN        NaN
# 137                                       Not assigned        NaN        NaN
# 138  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 139                                       Not assigned        NaN        NaN
# 140                                       Not assigned        NaN        NaN
# 141                                       Not assigned        NaN        NaN
# 142                                       Not assigned        NaN        NaN
# 143                                       Not assigned        NaN        NaN
# 144                                       Not assigned        NaN        NaN
# 145                                       Not assigned        NaN        NaN
# 146                                       Not assigned        NaN        NaN
# 147                                       Not assigned        NaN        NaN
# 148                                       Not assigned        NaN        NaN
# 149                                       Not assigned        NaN        NaN
# 150                                       Not assigned        NaN        NaN
# 151                                       Not assigned        NaN        NaN
# 152                                       Not assigned        NaN        NaN
# 153                                       Not assigned        NaN        NaN
# 154                                       Not assigned        NaN        NaN
# 155       Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 156  Alderwood, Toronto, Alderwood, Long Branch, To...  43.602414 -79.543484
# 157      The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 158  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 159  Kingsway Park South West, Mimico, Mimico NW, T...  43.628841 -79.520999
# 160                                   Islington Avenue  43.667856 -79.532242
# 161  Cloverdale, Islington, Toronto, Islington, Mar...  43.650943 -79.554724
# 162  Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 163                                       Not assigned        NaN        NaN
# 164                                       Not assigned        NaN        NaN
# 165                                       Not assigned        NaN        NaN
# 166                                       Not assigned        NaN        NaN
# 167                                       Not assigned        NaN        NaN
# 168                                      Humber Summit  43.756303 -79.565963
# 169                   Emery, Toronto, Emery, Humberlea  43.724766 -79.532242
# 170                            Weston, Toronto, Weston  43.706876 -79.518188
# 171                                          Westmount  43.696319 -79.532242
# 172  Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 173                                       Not assigned        NaN        NaN
# 174                                       Not assigned        NaN        NaN
# 175  Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 176                                          Northwest  43.706748 -79.594054
# 177                                       Not assigned        NaN        NaN
# 178                                       Not assigned        NaN        NaN
# 179                                       Not assigned        NaN        NaN
